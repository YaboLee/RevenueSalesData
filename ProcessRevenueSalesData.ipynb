# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
import numpy as np
import math

# %% [markdown]
# # Download all data

# %%
url = "http://www.revenue.state.il.us/LocalGovernment/Disbursements/SalesRelated/"
response = requests.get(url)
html = BeautifulSoup(response.text, "lxml")

# %%
download_links = []
for i in html.find_all("a"):
    href = i.get("href")
    if "sales" in href:
        download_links.append(url+href)
with open("download_links", "w+") as fd:
    for i in download_links:
        fd.write(i+"\n")

# %%
# !wget -i download_links -P data/
# Out:
# --2018-06-26 14:50:34--  http://www.revenue.state.il.us/LocalGovernment/Disbursements/SalesRelated/sales07160617.xlsx
# Resolving www.revenue.state.il.us (www.revenue.state.il.us)... 163.191.201.132
# Connecting to www.revenue.state.il.us (www.revenue.state.il.us)|163.191.201.132|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 308546 (301K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘data/sales07160617.xlsx.1’
#
# sales07160617.xlsx. 100%[===================>] 301.31K   161KB/s    in 1.9s
#
# 2018-06-26 14:50:36 (161 KB/s) - ‘data/sales07160617.xlsx.1’ saved [308546/308546]
#
# --2018-06-26 14:50:36--  http://www.revenue.state.il.us/LocalGovernment/Disbursements/SalesRelated/sales07150616.xlsx
# Reusing existing connection to www.revenue.state.il.us:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 303374 (296K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘data/sales07150616.xlsx.1’
#
# sales07150616.xlsx. 100%[===================>] 296.26K  71.3KB/s    in 4.2s
#
# 2018-06-26 14:50:40 (71.3 KB/s) - ‘data/sales07150616.xlsx.1’ saved [303374/303374]
#
# --2018-06-26 14:50:40--  http://www.revenue.state.il.us/LocalGovernment/Disbursements/SalesRelated/sales07140615.xlsx
# Reusing existing connection to www.revenue.state.il.us:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 321693 (314K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘data/sales07140615.xlsx.1’
#
# sales07140615.xlsx. 100%[===================>] 314.15K  79.8KB/s    in 3.9s
#
# 2018-06-26 14:50:44 (79.8 KB/s) - ‘data/sales07140615.xlsx.1’ saved [321693/321693]
#
# --2018-06-26 14:50:44--  http://www.revenue.state.il.us/LocalGovernment/Disbursements/SalesRelated/sales07130614.xlsx
# Reusing existing connection to www.revenue.state.il.us:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 318532 (311K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘data/sales07130614.xlsx.1’
#
# sales07130614.xlsx. 100%[===================>] 311.07K  83.7KB/s    in 3.7s
#
# 2018-06-26 14:50:49 (83.7 KB/s) - ‘data/sales07130614.xlsx.1’ saved [318532/318532]
#
# --2018-06-26 14:50:49--  http://www.revenue.state.il.us/LocalGovernment/Disbursements/SalesRelated/sales07120613.xlsx
# Reusing existing connection to www.revenue.state.il.us:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 392235 (383K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘data/sales07120613.xlsx.1’
#
# sales07120613.xlsx. 100%[===================>] 383.04K   225KB/s    in 1.7s
#
# 2018-06-26 14:50:51 (225 KB/s) - ‘data/sales07120613.xlsx.1’ saved [392235/392235]
#
# --2018-06-26 14:50:51--  http://www.revenue.state.il.us/LocalGovernment/Disbursements/SalesRelated/sales07110612.xls
# Reusing existing connection to www.revenue.state.il.us:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 602112 (588K) [application/vnd.ms-excel]
# Saving to: ‘data/sales07110612.xls.1’
#
# sales07110612.xls.1 100%[===================>] 588.00K   132KB/s    in 4.5s
#
# 2018-06-26 14:50:58 (132 KB/s) - ‘data/sales07110612.xls.1’ saved [602112/602112]
#
# --2018-06-26 14:50:58--  http://www.revenue.state.il.us/LocalGovernment/Disbursements/SalesRelated/sales07100611.pdf
# Reusing existing connection to www.revenue.state.il.us:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 455164 (444K) [application/pdf]
# Saving to: ‘data/sales07100611.pdf.1’
#
# sales07100611.pdf.1 100%[===================>] 444.50K   155KB/s    in 2.9s
#
# 2018-06-26 14:51:01 (155 KB/s) - ‘data/sales07100611.pdf.1’ saved [455164/455164]
#
# --2018-06-26 14:51:01--  http://www.revenue.state.il.us/LocalGovernment/Disbursements/SalesRelated/sales07090610.pdf
# Reusing existing connection to www.revenue.state.il.us:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 432109 (422K) [application/pdf]
# Saving to: ‘data/sales07090610.pdf.1’
#
# sales07090610.pdf.1 100%[===================>] 421.98K   396KB/s    in 1.1s
#
# 2018-06-26 14:51:02 (396 KB/s) - ‘data/sales07090610.pdf.1’ saved [432109/432109]
#
# --2018-06-26 14:51:02--  http://www.revenue.state.il.us/LocalGovernment/Disbursements/SalesRelated/sales07080609.pdf
# Reusing existing connection to www.revenue.state.il.us:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 455928 (445K) [application/pdf]
# Saving to: ‘data/sales07080609.pdf.1’
#
# sales07080609.pdf.1 100%[===================>] 445.24K  88.7KB/s    in 5.0s
#
# 2018-06-26 14:51:07 (88.7 KB/s) - ‘data/sales07080609.pdf.1’ saved [455928/455928]
#
# --2018-06-26 14:51:07--  http://www.revenue.state.il.us/LocalGovernment/Disbursements/SalesRelated/sales07070608.pdf
# Reusing existing connection to www.revenue.state.il.us:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 449482 (439K) [application/pdf]
# Saving to: ‘data/sales07070608.pdf.1’
#
# sales07070608.pdf.1 100%[===================>] 438.95K   114KB/s    in 3.9s
#
# 2018-06-26 14:51:11 (114 KB/s) - ‘data/sales07070608.pdf.1’ saved [449482/449482]
#
# --2018-06-26 14:51:11--  http://www.revenue.state.il.us/LocalGovernment/Disbursements/SalesRelated/sales07060607.pdf
# Reusing existing connection to www.revenue.state.il.us:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 442618 (432K) [application/pdf]
# Saving to: ‘data/sales07060607.pdf.1’
#
# sales07060607.pdf.1 100%[===================>] 432.24K   399KB/s    in 1.1s
#
# 2018-06-26 14:51:13 (399 KB/s) - ‘data/sales07060607.pdf.1’ saved [442618/442618]
#
# --2018-06-26 14:51:13--  http://www.revenue.state.il.us/LocalGovernment/Disbursements/SalesRelated/sales07050606.pdf
# Reusing existing connection to www.revenue.state.il.us:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 411476 (402K) [application/pdf]
# Saving to: ‘data/sales07050606.pdf.1’
#
# sales07050606.pdf.1 100%[===================>] 401.83K   383KB/s    in 1.1s
#
# 2018-06-26 14:51:14 (383 KB/s) - ‘data/sales07050606.pdf.1’ saved [411476/411476]
#
# FINISHED --2018-06-26 14:51:14--
# Total wall clock time: 40s
# Downloaded: 12 files, 4.7M in 35s (137 KB/s)

# %% [markdown]
# # Convert pdf to csv
# I use tabula, a java package, to grab table in a pdf file and convert it to csv.
#
# However, due to the scheme of the original file, we need to deal with the rows and columns. Before 2013, month information is not in onw row.
#
# As you can see in the following comparison between the original csv and output, the framework of the data has been changed.
#
# For further analysis, I add a new column, "Span", which distinguishes the row with same element.

# %%
# Run this command in terminal in directory data/
# This script uses tabula to grab table in a pdf file and convert it to csv
# !./pdf2csv.sh
# Out:
# /bin/sh: 1: ./pdf2csv.sh: not found

# %%
new_csvs = []
for i in os.listdir("data/"):
    if ".csv" in i:
        new_csvs.append(i)
# Deal with rows and cols
for csv in new_csvs:
    span = csv[5:13] # indicates the span this csv covers
    df = pd.read_csv("data/"+csv)
    df = df.drop(range(60,len(df),61), axis=0) # remove unnecessary rows eg:repeated scheme
    df = df.reset_index(drop=True)
    # Rename columns
    df.columns = ["LocalGovernment", "Tax", "Vendor#", "Temp", "JUL", "AUG", "SEP", "OCT", "NOV", "DEC", "FY_total"]
    # The following is to move Jan-Jun to the same row as Jul-Dec
    jan2jun = df.iloc[1::2, 4:].reset_index(drop=True)
    jan2jun.columns = ["JAN", "FEB", "MAR", "APR", "MAY", "JUN", "FY_total"]
    df = df.drop(range(1, len(df), 2), axis=0).reset_index(drop=True)
    for i in jan2jun.columns:
        df[i] = jan2jun[:][i]
    df = df.drop("Temp", axis=1).reset_index(drop=True)
    df = df.dropna(how="all")
    df["Span"] = np.array([span]*len(df))
    # tax data should be float type
    for i in range(3, 16):
        df.iloc[:, i] = df.iloc[:, i].map(lambda x: float(x.replace(",", "")))
    df.iloc[:, 2] = df.iloc[:, 2].map(lambda x: str(int(x)) if not math.isnan(x) else x) # Vender# should be string
    df.to_csv("sales"+span, index=False)

# %%
# Original csv
pd.read_csv("data/sales07100611.pdf.csv")
# Out:
#       Local GovernmentTaxVendor #FY Total Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 0                                ABINGDON         MT  390000010.0  JUL - DEC
# 1                                     NaN        NaN          NaN  JAN - JUN
# 2                 ADAMS COUNTY GOVERNMENT        CST  290000001.0  JUL - DEC
# 3                                     NaN        NaN          NaN  JAN - JUN
# 4                 ADAMS COUNTY GOVERNMENT         CT  290000001.0  JUL - DEC
# 5                                     NaN        NaN          NaN  JAN - JUN
# 6                              ADDIEVILLE         MT  390000018.0  JUL - DEC
# 7                                     NaN        NaN          NaN  JAN - JUN
# 8                                 ADDISON        HMR  390000029.0  JUL - DEC
# 9                                     NaN        NaN          NaN  JAN - JUN
# 10                                ADDISON         MT  390000029.0  JUL - DEC
# 11                                    NaN        NaN          NaN  JAN - JUN
# 12                                ADDISON      MTART  390000029.0  JUL - DEC
# 13                                    NaN        NaN          NaN  JAN - JUN
# 14                                ADELINE         MT  390000030.0  JUL - DEC
# 15                                    NaN        NaN          NaN  JAN - JUN
# 16                                 ALBANY         MT  390000020.0  JUL - DEC
# 17                                    NaN        NaN          NaN  JAN - JUN
# 18                                 ALBERS         MT  390000045.0  JUL - DEC
# 19                                    NaN        NaN          NaN  JAN - JUN
# 20                                 ALBION         MT  390000050.0  JUL - DEC
# 21                                    NaN        NaN          NaN  JAN - JUN
# 22                                  ALEDO         MT  390000060.0  JUL - DEC
# 23                                    NaN        NaN          NaN  JAN - JUN
# 24            ALEXANDER COUNTY GOVERNMENT        CST  290000003.0  JUL - DEC
# 25                                    NaN        NaN          NaN  JAN - JUN
# 26            ALEXANDER COUNTY GOVERNMENT         CT  290000003.0  JUL - DEC
# 27                                    NaN        NaN          NaN  JAN - JUN
# 28                                 ALEXIS         MT  390000070.0  JUL - DEC
# 29                                    NaN        NaN          NaN  JAN - JUN
# ...                                   ...        ...          ...        ...
# 4007                            WOODSTOCK      MTART  390009560.0  JUL - DEC
# 4008                                  NaN        NaN          NaN  JAN - JUN
# 4009                               WORDEN         MT  390009570.0  JUL - DEC
# 4010                                  NaN        NaN          NaN  JAN - JUN
# 4011                                WORTH         MT  390009580.0  JUL - DEC
# 4012                                  NaN        NaN          NaN  JAN - JUN
# 4013                                WORTH      MTART  390009580.0  JUL - DEC
# 4014                                  NaN        NaN          NaN  JAN - JUN
# 4015                               WYANET         MT  390009590.0  JUL - DEC
# 4016                                  NaN        NaN          NaN  JAN - JUN
# 4017                              WYOMING         MT  390009600.0  JUL - DEC
# 4018                                  NaN        NaN          NaN  JAN - JUN
# 4019                                XENIA         MT  390009610.0  JUL - DEC
# 4020                                  NaN        NaN          NaN  JAN - JUN
# 4021                                 YALE         MT  390009616.0  JUL - DEC
# 4022                                  NaN        NaN          NaN  JAN - JUN
# 4023                           YATES CITY         MT  390009620.0  JUL - DEC
# 4024                                  NaN        NaN          NaN  JAN - JUN
# 4025  Local GovernmentTaxVendor #FY Total        NaN          NaN        NaN
# 4026                            YORKVILLE         MT  390009630.0  JUL - DEC
# 4027                                  NaN        NaN          NaN  JAN - JUN
# 4028                            YORKVILLE      MTART  390009630.0  JUL - DEC
# 4029                                  NaN        NaN          NaN  JAN - JUN
# 4030                              ZEIGLER         MT  390009640.0  JUL - DEC
# 4031                                  NaN        NaN          NaN  JAN - JUN
# 4032                                 ZION         MT  390009650.0  JUL - DEC
# 4033                                  NaN        NaN          NaN  JAN - JUN
# 4034                                TOTAL        NaN          NaN  JUL - DEC
# 4035                                  NaN        NaN          NaN  JAN - JUN
# 4036                                  NaN        NaN          NaN        NaN
#
#           Unnamed: 4      Unnamed: 5      Unnamed: 6      Unnamed: 7  \
# 0          13,641.08       17,114.13       16,600.83       15,020.00
# 1          15,165.40       13,950.87       16,010.03       12,447.11
# 2         150,484.34      168,827.75      183,551.91      165,368.23
# 3         203,475.61      185,012.67      219,194.07      133,647.28
# 4          46,403.85       29,058.04       46,075.88       44,608.86
# 5         181,700.29       42,695.32       44,107.32       29,748.19
# 6           3,288.19        3,201.13        4,850.22        3,495.84
# 7           3,074.30        4,748.87        2,663.88        1,024.98
# 8         367,251.20      366,446.79      410,460.87      384,395.38
# 9         397,488.00      385,376.73      454,824.86      334,609.25
# 10        575,239.13      594,755.65      668,820.13      608,616.87
# 11        629,556.39      609,306.89      711,923.30      546,869.52
# 12            125.11          116.34          181.20          203.45
# 13            216.40          162.30          160.48          187.90
# 14             43.52           53.76           37.56          119.20
# 15             74.56           58.72           99.40           91.20
# 16          3,426.15        7,045.38        5,437.27        4,071.40
# 17          4,062.53        2,244.66        3,210.44        2,194.02
# 18          4,977.20        6,687.05        5,339.24        5,527.34
# 19          6,372.10        5,817.14        7,971.13        5,809.65
# 20         18,134.82       23,127.75       24,836.44       19,708.97
# 21         21,175.63       23,221.95       21,538.04       16,035.97
# 22         44,590.12       52,363.68       50,012.03       54,484.35
# 23         53,050.44       54,816.68       63,003.64       51,008.74
# 24          4,332.13        4,813.01        3,989.96        5,033.17
# 25          4,679.82        4,568.07        4,541.53        4,017.85
# 26          4,744.06        4,356.60        3,946.56        4,655.97
# 27          4,426.56        3,555.50        5,828.70        3,517.30
# 28          3,787.39        2,897.45        1,962.04        3,025.80
# 29          2,854.71        2,473.87        6,251.04        1,244.81
# ...              ...             ...             ...             ...
# 4007          434.93          404.19          796.06          720.17
# 4008          597.29          444.86          718.32          630.75
# 4009        3,435.66        2,718.99        3,727.57        3,941.62
# 4010        2,909.60        2,490.71        2,645.14        2,548.02
# 4011       72,192.90       76,707.22       77,193.84       73,290.18
# 4012       59,583.08       61,172.49       67,137.36       59,072.11
# 4013          567.77          267.69           59.04           32.48
# 4014           30.34           40.35           37.40           31.49
# 4015        4,269.37        2,253.25        3,348.66        3,232.40
# 4016        3,000.20        2,979.29        3,862.76        3,164.16
# 4017       13,198.26        9,386.17       11,568.38        9,019.29
# 4018       15,572.36       14,707.17       21,605.43       13,825.74
# 4019        7,563.95        7,490.13        7,964.14        6,912.47
# 4020        7,825.87       10,681.24        5,685.19       10,846.25
# 4021        2,886.38        1,376.49        1,441.08          762.08
# 4022        2,196.45          985.57        1,104.90          954.51
# 4023        1,670.02        2,132.28        1,961.25        1,788.31
# 4024        1,835.43        1,614.71        1,863.21        1,364.62
# 4025             NaN             NaN             NaN             NaN
# 4026      218,349.13      224,744.02      238,912.13      217,924.53
# 4027      217,052.07      222,025.63      237,910.96      174,391.28
# 4028          578.60          528.60          699.63          715.37
# 4029          623.86          601.23          770.48          700.61
# 4030        6,934.24       12,737.90       16,888.04       13,017.42
# 4031        8,834.09        6,565.81        5,293.36        7,635.35
# 4032      207,036.71      226,902.60      199,426.08      198,147.34
# 4033      211,367.37      242,402.17      189,019.48      162,490.26
# 4034  357,234,713.13  373,060,178.26  399,443,723.09  362,414,737.24
# 4035  359,320,027.23  370,508,415.29  444,568,758.64  308,682,864.90
# 4036             NaN             NaN             NaN             NaN
#
#           Unnamed: 8      Unnamed: 9       Unnamed: 10
# 0          13,557.00       15,437.33               NaN
# 1          13,731.71       15,527.35        178,202.84
# 2         154,026.52      158,484.38               NaN
# 3         146,933.53      164,238.97      2,033,245.26
# 4          41,027.63       47,996.68               NaN
# 5          30,176.41       40,821.14        624,419.61
# 6           3,228.25        3,039.54               NaN
# 7           4,048.33        3,709.58         40,373.11
# 8         370,117.31      378,246.27               NaN
# 9         317,153.72      393,603.73      4,559,974.11
# 10        586,234.99      600,545.64               NaN
# 11        520,825.64      641,189.40      7,293,883.55
# 12            264.84          129.76               NaN
# 13            119.06          184.04          2,050.88
# 14             31.20           48.48               NaN
# 15             38.56           54.08            750.24
# 16          3,879.88        2,749.76               NaN
# 17          3,059.78        2,860.88         44,242.15
# 18          6,191.97        4,888.23               NaN
# 19          6,423.81        6,904.05         72,908.91
# 20         21,029.88       19,922.66               NaN
# 21         18,990.42       20,428.85        248,151.38
# 22         52,262.84       51,726.06               NaN
# 23         51,388.00       51,107.39        629,813.97
# 24          3,752.01        4,377.80               NaN
# 25          4,583.36        4,649.66         53,338.37
# 26          3,605.94        4,998.58               NaN
# 27          4,138.06        7,229.59         55,003.42
# 28          2,513.63        2,072.94               NaN
# 29            968.49        1,237.75         31,289.92
# ...              ...             ...               ...
# 4007          720.29          493.67               NaN
# 4008          593.15        1,391.89          7,945.57
# 4009        3,132.96        3,232.74               NaN
# 4010        2,198.09        2,335.51         35,316.61
# 4011       67,129.36       67,968.98               NaN
# 4012       53,396.61       71,472.77        806,316.90
# 4013           19.68           41.38               NaN
# 4014           25.57           23.07          1,176.26
# 4015        3,079.44        3,247.22               NaN
# 4016        2,904.16        3,201.65         38,542.56
# 4017        9,891.10       10,557.77               NaN
# 4018       12,433.75        9,745.51        151,510.93
# 4019        8,372.58        6,707.51               NaN
# 4020        6,582.10        9,613.03         96,244.46
# 4021        1,242.85        2,638.61               NaN
# 4022        1,345.98        1,104.18         18,039.08
# 4023        1,689.04        1,998.17               NaN
# 4024        1,340.57        1,611.52         20,869.13
# 4025             NaN             NaN               NaN
# 4026      217,044.98      221,211.44               NaN
# 4027      169,092.88      210,573.52      2,569,232.57
# 4028          791.14          691.76               NaN
# 4029          687.18          909.23          8,297.69
# 4030        5,623.99       13,001.10               NaN
# 4031        6,790.05       10,552.90        113,874.25
# 4032      171,213.37      220,997.41               NaN
# 4033      164,055.69      190,272.23      2,383,330.71
# 4034  366,092,572.88  364,416,936.02               NaN
# 4035  318,435,293.30  377,422,482.15  4,401,600,702.13
# 4036             NaN             NaN               NaN
#
# [4037 rows x 11 columns]

# %%
# Output csv
df
# Out:
#                   LocalGovernment    Tax    Vendor#           JUL  \
# 0                        ABINGDON     MT  390000010  1.362733e+04
# 1         ADAMS COUNTY GOVERNMENT    CST  290000001  1.524827e+05
# 2         ADAMS COUNTY GOVERNMENT     CT  290000001  4.181071e+04
# 3                      ADDIEVILLE     MT  390000018  2.915070e+03
# 4                         ADDISON    HMR  390000029  3.798454e+05
# 5                         ADDISON     MT  390000029  5.882272e+05
# 6                         ADDISON  MTART  390000029  2.757000e+01
# 7                         ADELINE     MT  390000030  6.016000e+01
# 8                          ALBANY     MT  390000020  4.251870e+03
# 9                          ALBERS     MT  390000045  5.650210e+03
# 10                         ALBION     MT  390000050  1.759101e+04
# 11                          ALEDO     MT  390000060  5.003472e+04
# 12    ALEXANDER COUNTY GOVERNMENT    CST  290000003  4.970960e+03
# 13    ALEXANDER COUNTY GOVERNMENT     CT  290000003  4.188860e+03
# 14                         ALEXIS     MT  390000070  2.657860e+03
# 15                      ALGONQUIN    HMR  390000080  2.801244e+05
# 16                      ALGONQUIN     MT  390000080  5.142365e+05
# 17                       ALHAMBRA     MT  390000090  2.325030e+03
# 18                      ALLENDALE     MT  390000100  9.887100e+02
# 19                     ALLENVILLE     MT  390000105  2.048000e+02
# 20                       ALLERTON     MT  390000108  1.776860e+03
# 21                           ALMA     MT  390000110  1.048690e+03
# 22                        ALORTON     MT  390000120  2.094031e+04
# 23                          ALPHA     MT  390000130  2.137250e+03
# 24                          ALSEY     MT  390000139  3.765300e+02
# 25                          ALSIP    HMR  390000140  1.507094e+05
# 26                          ALSIP     MT  390000140  2.757995e+05
# 27                          ALSIP  MTART  390000140  2.165000e+01
# 28                       ALTAMONT     MT  390000150  2.315623e+04
# 29                      ALTO PASS     MT  390000180  1.181940e+03
# ...                           ...    ...        ...           ...
# 1919                         WITT     MT  390009490  1.935000e+03
# 1920                  WONDER LAKE     MT  380009500  5.304930e+03
# 1921                    WOOD DALE     MT  390009510  2.410469e+05
# 1922                    WOOD DALE   NHMR  390009510  0.000000e+00
# 1923                   WOOD RIVER     MT  390009550  2.105288e+05
# 1924                   WOOD RIVER  MTART  390009550  5.910000e+00
# 1925   WOODFORD COUNTY GOVERNMENT    CST  290000203  5.557924e+04
# 1926   WOODFORD COUNTY GOVERNMENT     CT  290000203  3.187828e+04
# 1927   WOODFORD COUNTY GOVERNMENT   CTPS  290000203  1.325496e+05
# 1928                     WOODHULL     MT  390009520  7.726070e+03
# 1929                     WOODLAND     MT  390009530  1.448000e+01
# 1930                     WOODLAWN     MT  390009540  2.150830e+03
# 1931                    WOODRIDGE    HMR  390009545  1.381179e+05
# 1932                    WOODRIDGE     MT  390009545  3.537747e+05
# 1933                      WOODSON     MT  390009555  1.240000e+02
# 1934                    WOODSTOCK     MT  390009560  3.035023e+05
# 1935                    WOODSTOCK  MTART  390009560  5.136500e+02
# 1936                       WORDEN     MT  390009570  3.777720e+03
# 22    1.998909e+04  2.426407e+04  07070608
# 23    5.650040e+03  2.963660e+03  07070608
# 24    3.958500e+02  2.601700e+02  07070608
# 25    1.376052e+05  1.650250e+05  07070608
# 26    2.535638e+05  2.977760e+05  07070608
# 27    4.330000e+01  2.461000e+01  07070608
# 28    1.927168e+04  1.898781e+04  07070608
# 29    4.473300e+02  5.767400e+02  07070608
# ...            ...           ...       ...
# 1919  1.482200e+03  1.645990e+03  07070608
# 1920  3.268570e+03  4.419910e+03  07070608
# 1921  2.102368e+05  2.348179e+05  07070608
# 1922  1.634030e+05  1.869656e+05  07070608
# 1923  2.155349e+05  2.361569e+05  07070608
# 1924  1.675000e+01  1.575000e+01  07070608
# 1925  4.326574e+04  5.198121e+04  07070608
# 1926  2.075369e+04  2.634415e+04  07070608
# 1927  1.060490e+05  1.302402e+05  07070608
# 1928  4.706540e+03  6.163100e+03  07070608
# 1929  1.138000e+01  1.440500e+02  07070608
# 1930  2.369960e+03  1.857380e+03  07070608
# 1931  1.217199e+05  1.356967e+05  07070608
# 1932  3.178695e+05  3.523634e+05  07070608
# 1933  3.433000e+02  2.292800e+02  07070608
# 1934  2.569092e+05  2.867040e+05  07070608
# 1935  7.792600e+02  5.402200e+02  07070608
# 1936  2.331180e+03  1.986680e+03  07070608
# 1937  5.464708e+04  6.006162e+04  07070608
# 1938  7.931100e+02  6.418400e+02  07070608
# 1939  3.066570e+03  4.443280e+03  07070608
# 1940  1.665130e+04  1.917506e+04  07070608
# 1941  6.674630e+03  1.050584e+04  07070608
# 1942  1.579350e+03  1.473340e+03  07070608
# 1943  1.170370e+03  9.195100e+02  07070608
# 1944  1.626759e+05  1.820844e+05  07070608
# 1945  3.089800e+02  3.355500e+02  07070608
# 1946  6.587660e+03  9.680870e+03  07070608
# 1947  1.447899e+05  1.819997e+05  07070608
# 1948  2.751766e+08  3.073632e+08  07070608
#
# [1949 rows x 17 columns]

# %%
df.dtypes
# Out:
# LocalGovernment     object
# Tax                 object
# Vendor#             object
# JUL                float64
# AUG                float64
# SEP                float64
# OCT                float64
# NOV                float64
# DEC                float64
# FY_total           float64
# JAN                float64
# FEB                float64
# MAR                float64
# APR                float64
# MAY                float64
# JUN                float64
# Span                object
# dtype: object

# %% [markdown]
# # Deal with xlsx file
# In 11-12 and 12-13, month infomation is not in the same row. So I try to manipulate them.

# %%
# Deal with 07110612
df = pd.read_excel("data/sales07110612.xls", skiprows=5)
span = "07110612"
df.columns = ["LocalGovernment", "Tax", "Vendor#", "Temp", "JUL", "AUG", "SEP", "OCT", "NOV", "DEC", "FY_total"]
# The following is to move Jan-Jun to the same row as Jul-Dec
jan2jun = df.iloc[1::2, 4:].reset_index(drop=True)
jan2jun.columns = ["JAN", "FEB", "MAR", "APR", "MAY", "JUN", "FY_total"]
df = df.drop(range(1, len(df), 2), axis=0).reset_index(drop=True)
for i in jan2jun.columns:
    df[i] = jan2jun[:][i]
df = df.drop("Temp", axis=1).reset_index(drop=True)
df = df.dropna(how="all")
df["Span"] = np.array([span]*len(df))
df.iloc[:, 2] = df.iloc[:, 2].map(lambda x: str(int(x)) if not math.isnan(x) else x) # Vender# should be string
df.to_csv("sales"+span, index=False)

# %%
# Deal with 07120613
df = pd.read_excel("data/sales07120613.xlsx", skiprows=5)
span = "07120613"
df.columns = ["LocalGovernment", "Tax", "Vendor#", "Temp", "JUL", "AUG", "SEP", "OCT", "NOV", "DEC", "FY_total"]
# The following is to move Jan-Jun to the same row as Jul-Dec
jan2jun = df.iloc[1::2, 4:].reset_index(drop=True)
jan2jun.columns = ["JAN", "FEB", "MAR", "APR", "MAY", "JUN", "FY_total"]
df = df.drop(range(1, len(df), 2), axis=0).reset_index(drop=True)
for i in jan2jun.columns:
    df[i] = jan2jun[:][i]
df = df.drop("Temp", axis=1).reset_index(drop=True)
df = df.dropna(how="all")
df["Span"] = np.array([span]*len(df))
df.iloc[:, 2] = df.iloc[:, 2].map(lambda x: str(int(x)) if not math.isnan(x) else x) # Vender# should be string
df.to_csv("sales"+span, index=False)

# %%
df.dtypes
# Out:
# LocalGovernment     object
# Tax                 object
# Vendor#             object
# JUL                float64
# AUG                float64
# SEP                float64
# OCT                float64
# NOV                float64
# DEC                float64
# FY_total           float64
# JAN                float64
# FEB                float64
# MAR                float64
# APR                float64
# MAY                float64
# JUN                float64
# Span                object
# dtype: object

# %%
df
# Out:
#                   LocalGovernment    Tax    Vendor#           JUL  \
# 0                        ABINGDON     MT  390000010  1.722710e+04
# 1         ADAMS COUNTY GOVERNMENT    CST  290000001  1.626250e+05
# 2         ADAMS COUNTY GOVERNMENT     CT  290000001  4.704802e+04
# 3                      ADDIEVILLE     MT  390000018  4.017390e+03
# 4                         ADDISON    HMR  390000029  5.115589e+05
# 5                         ADDISON     MT  390000029  6.227223e+05
# 6                         ADDISON  MTART  390000029  7.957000e+01
# 7                         ADELINE     MT  390000030  7.632000e+01
# 8                          ALBANY     MT  390000020  4.279290e+03
# 9                          ALBERS     MT  390000045  7.649310e+03
# 10                         ALBION     MT  390000050  2.778306e+04
# 11                          ALEDO     MT  390000060  5.144771e+04
# 12    ALEXANDER COUNTY GOVERNMENT    CST  290000003  4.638170e+03
# 13    ALEXANDER COUNTY GOVERNMENT     CT  290000003  4.676310e+03
# 14                         ALEXIS     MT  390000070  1.983310e+03
# 15                      ALGONQUIN    HMR  390000080  2.899148e+05
# 16                      ALGONQUIN     MT  390000080  5.479047e+05
# 17                       ALHAMBRA     MT  390000090  3.991470e+03
# 18                      ALLENDALE     MT  390000100  2.607140e+03
# 19                     ALLENVILLE     MT  390000105  3.154000e+02
# 20                       ALLERTON     MT  390000108  2.068270e+03
# 21                           ALMA     MT  390000110  3.906600e+02
# 22                        ALORTON     MT  390000120  1.164063e+04
# 23                          ALPHA     MT  390000130  3.222570e+03
# 24                          ALSEY     MT  390000139  4.058000e+02
# 25                          ALSIP    HMR  390000140  1.636483e+05
# 26                          ALSIP     MT  390000140  2.754949e+05
# 27                          ALSIP  MTART  390000140  1.080430e+03
# 28                       ALTAMONT     MT  390000150  2.102691e+04
# 29                      ALTO PASS     MT  390000180  6.302600e+02
# ...                           ...    ...        ...           ...
# 1984                  WONDER LAKE     MT  380009500  3.740030e+03
# 1985                    WOOD DALE     MT  390009510  2.523712e+05
# 1986                    WOOD DALE  MTART  390009510  5.609000e+01
